# %% [markdown]
# ### Uso del Markdowns Basico
# ---

# %% [markdown]
# Esto nos ayuda a documentar una notebook
# - Generar un encabezado y saber que hace la notebook

# %% [markdown]
# Si utiliza + codigo, para transformar en markdowns utilice %md

# %% [markdown]
# # Titulo
# ## Titulo
# ### Titulo
# #### Titulo

# %% [markdown]
# - Listas
#   - uno
#   - dos
#   - tres
#   - cuatro

# %% [markdown]
# ```
# Utiliza las tres
# comillas, para escribir en
# esta forma
# ```

# %% [markdown]
# - **Negrita**
# -  *italic*
